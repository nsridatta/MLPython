# %% [markdown]
# <a href="https://colab.research.google.com/github/nsridatta/MLPython/blob/ML-Projects/RulebasedSentimentAnalyzer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install tweepy
# !pip install vaderSentiment
# Out:
# ...
#     100% |████████████████████████████████| 133kB 6.3MB/s
# ...

# %%
import tweepy
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
#My Twitter API Authentication Variables
#The below credentials can be obtained from https://developer.twitter.com/en/apps/
consumer_api_key = 'VWLJxdeB3AqBIi7a4ZE3xSCV9'
consumer_api_secret = 'jjrMvi3bN5tqKf3tLkEm3jTQCXHHy5K3NxNdYQtHQA9fuFBJyd'
twitter_access_token = '176452731-5euP0bVIcZw99qfDFMjWxgICxoucgcm0F2och8P4'
twitter_access_token_secret = 'bs6J9tMwc2L7VqOTgtYSu3GWm9Y620x3U91SpEA7vgMw5'

# %%
auth = tweepy.OAuthHandler(consumer_api_key, consumer_api_secret)
auth.set_access_token(twitter_access_token, twitter_access_token_secret)

api = tweepy.API(auth)

tweets = api.search('Apple Watch', count=200)


data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

display(data.head(50))


print(tweets[0].created_at)
# Out:
#                                                Tweets
# 0   RT @ThePME: State of Golf —  Masters, PGA TV C...
# 1   RT @BebeXProject: Current status! @steveaoki @...
# 2   RT @lukecombs: Listen to “Brand New Man” and t...
# 3   Reddit user says Apple Watch helped him detect...
# 4   RT @LouisMxOficial: Recuerden que tenemos una ...
# 5   RT @lukecombs: Listen to “Brand New Man” and t...
# 6   Apple &amp; Android Compatible 15-in-1 GSM Sma...
# 7   RT @apiper13: Fred Trump cheated the gov't, br...
# 8   #TwoOfUsStreamingSession\n\nApple Music: https...
# 9   RT @billieeilish: Watch Billie’s full intervie...
# 10  Dice Funk S5: Part 29 - Freudian Insertion\n\n...
# 11  RT @LouisMxOficial: Recuerden que tenemos una ...
# 12  RT @JoelOsteen: The way to honor God is to go ...
# 13  If you wear your Apple Watch OVER your long sl...
# 14  RT @apiper13: Fred Trump cheated the gov't, br...
# 15  RT @JoelOsteen: The way to honor God is to go ...
# ...

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
#Rule based Model
sid = SentimentIntensityAnalyzer()

#Declare a list to store the list of tweets
listy = []

for index, row in data.iterrows():
  ss = sid.polarity_scores(row["Tweets"])
  listy.append(ss)
  
se = pd.Series(listy)
data['polarity'] = se.values
#Display first 100 sentiment values with polarity
display(data.head(100))
# Out:
#                                                Tweets  \
# 0   RT @ThePME: State of Golf —  Masters, PGA TV C...
# 1   RT @BebeXProject: Current status! @steveaoki @...
# 2   RT @lukecombs: Listen to “Brand New Man” and t...
# 3   Reddit user says Apple Watch helped him detect...
# 4   RT @LouisMxOficial: Recuerden que tenemos una ...
# 5   RT @lukecombs: Listen to “Brand New Man” and t...
# 6   Apple &amp; Android Compatible 15-in-1 GSM Sma...
# 7   RT @apiper13: Fred Trump cheated the gov't, br...
# 8   #TwoOfUsStreamingSession\n\nApple Music: https...
# 9   RT @billieeilish: Watch Billie’s full intervie...
# 10  Dice Funk S5: Part 29 - Freudian Insertion\n\n...
# 11  RT @LouisMxOficial: Recuerden que tenemos una ...
# 12  RT @JoelOsteen: The way to honor God is to go ...
# 13  If you wear your Apple Watch OVER your long sl...
# 14  RT @apiper13: Fred Trump cheated the gov't, br...
# 15  RT @JoelOsteen: The way to honor God is to go ...
# ...
